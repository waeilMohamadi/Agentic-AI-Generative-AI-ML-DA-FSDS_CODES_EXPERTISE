# %% [markdown]
# # KAGGLE PANDAS PROJECT

# %%
import pandas as pn #import libraries

# %%
ratings = pn.read_csv(r'C:\Users\THINKPAD E15\Desktop\Kaggle-projec\rating.csv') #ratings.csv

# %%
ratings
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
del ratings['timestamp']

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
movies = pn.read_csv(r'C:\Users\THINKPAD E15\Desktop\Kaggle-projec\movie.csv',sep=',') #movies.csv

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
tags = pn.read_csv(r'C:\Users\THINKPAD E15\Desktop\Kaggle-projec\tag.csv') #tags.csv

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
del tags['timestamp']

# %%
print(tags.columns)
print(ratings.columns)
print(movies.columns)
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
tags.head(3)
# Out:
#    userId  movieId          tag            timestamp
# 0      18     4141  Mark Waters  2009-04-24 18:19:40
# 1      65      208    dark hero  2013-05-10 01:41:18
# 2      65      353    dark hero  2013-05-10 01:41:19

# %%
tags.iloc[0]
# Out:
# userId                        18
# movieId                     4141
# tag                  Mark Waters
# timestamp    2009-04-24 18:19:40
# Name: 0, dtype: object

# %% [markdown]
# # Data Structures:

# %% [markdown]
# # Series

# %%
row_0 = tags.iloc[0]
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
type(row_0)
# Out:
# pandas.core.series.Series

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row_0['userId']
# Out:
# np.int64(18)

# %%
row_0['movieId']
# Out:
# np.int64(4141)

# %%
'rating' in row_0
# Out:
# False

# %%
'tag' in row_0
# Out:
# True

# %%
row_0.name
# Out:
# 0

# %%
row_0 = row_0.rename('firstRow')
row_0.name
# Out:
# 'firstRow'

# %% [markdown]
# # DataFrames

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,11,500]]
# Out:
#      userId  movieId                tag
# 0        18     4141        Mark Waters
# 11       65     1783      noir thriller
# 500     342    55908  entirely dialogue

# %%
tags.iloc[:5]
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.iloc[:-1]
# Out:
#         userId  movieId                 tag
# 0           18     4141         Mark Waters
# 1           65      208           dark hero
# 2           65      353           dark hero
# 3           65      521       noir thriller
# 4           65      592           dark hero
# ...        ...      ...                 ...
# 465558  138446     7164  visually appealing
# 465559  138446    55999             dragged
# 465560  138446    55999       Jason Bateman
# 465561  138446    55999              quirky
# 465562  138446    55999                 sad
#
# [465563 rows x 3 columns]

# %%
tags.iloc[5:10]
# Out:
#    userId  movieId               tag
# 5      65      668         bollywood
# 6      65      898  screwball comedy
# 7      65     1248     noir thriller
# 8      65     1391              mars
# 9      65     1617          neo-noir

# %%
tags.iloc[::-2]
# Out:
#         userId  movieId              tag
# 465563  138472      923    rise to power
# 465561  138446    55999           quirky
# 465559  138446    55999          dragged
# 465557  138446     7164        Peter Pan
# 465555  138446     7045  family friendly
# ...        ...      ...              ...
# 9           65     1617         neo-noir
# 7           65     1248    noir thriller
# 5           65      668        bollywood
# 3           65      521    noir thriller
# 1           65      208        dark hero
#
# [232782 rows x 3 columns]

# %% [markdown]
# # Descriptive Statistics

# %%
ratings
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings.max()
# Out:
# userId     138493.0
# movieId    131262.0
# rating          5.0
# dtype: float64

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings.min()
# Out:
# userId     1.0
# movieId    1.0
# rating     0.5
# dtype: float64

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %% [markdown]
# # Filter The DataSet

# %%
filter1 = ratings['rating']>10
print(filter1)
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# False

# %%
print(filter1.any())
# Out:
# False

# %%
filter2 = ratings['rating'] > 0
filter2.all()
# Out:
# np.True_

# %% [markdown]
# # Data Cleaning: Handling Missing Data

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull()
# Out:
#        movieId  title  genres
# 0        False  False   False
# 1        False  False   False
# 2        False  False   False
# 3        False  False   False
# 4        False  False   False
# ...        ...    ...     ...
# 27273    False  False   False
# 27274    False  False   False
# 27275    False  False   False
# 27276    False  False   False
# 27277    False  False   False
#
# [27278 rows x 3 columns]

# %%
movies.isnull().any().any()
# Out:
# np.False_

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
ratings.isnull().any().any()
# Out:
# np.False_

# %%
tags.shape
# Out:
# (465564, 3)

# %%
tags.isnull().any().any() #We have some tags which are NULL
# Out:
# np.True_

# %%
tags=tags.dropna()

# %%
tags.isnull().any().any()
# Out:
# np.False_

# %%
tags.shape #Thats nice ! No NULL values ! Notice the number of lines have reduced.
# Out:
# (465548, 3)

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
ratings.hist(column='rating', figsize=(8,4))
plt.show()

# %%
ratings.boxplot(column='rating', figsize=(8,4))
plt.show()

# %% [markdown]
# # Slicing Out Columns

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# tag
# chiptunes         1
# ewan macgregor    1
# Disguises         1
# retarted          1
# operatic          1
# heartrending      1
# film crew         1
# es                1
# girltalk          1
# Spanish films     1
# Name: count, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(8,4))
plt.show()

# %% [markdown]
# #  Filters for Selecting Rows

# %%
is_highly_rated = ratings['rating'] >= 5.0
is_highly_rated
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261     True
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool

# %%
ratings[is_highly_rated][30:50]
# Out:
#      userId  movieId  rating
# 239       3       50     5.0
# 242       3      175     5.0
# 244       3      223     5.0
# 245       3      260     5.0
# 246       3      316     5.0
# 247       3      318     5.0
# 248       3      329     5.0
# 252       3      457     5.0
# 253       3      480     5.0
# 254       3      490     5.0
# 256       3      541     5.0
# 258       3      593     5.0
# 263       3      858     5.0
# 264       3      904     5.0
# 267       3      924     5.0
# 268       3      953     5.0
# 271       3     1060     5.0
# 272       3     1073     5.0
# 275       3     1084     5.0
# 276       3     1089     5.0

# %%
is_action= movies['genres'].str.contains('Action')
is_action
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27273    False
# 27274    False
# 27275    False
# 27276    False
# 27277    False
# Name: genres, Length: 27278, dtype: bool

# %%
movies[is_action][5:15]
# Out:
#     movieId                                      title  \
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                            genres
# 22          Action|Crime|Thriller
# 41             Action|Crime|Drama
# 43       Action|Adventure|Fantasy
# 50          Action|Drama|Thriller
# 65         Action|Sci-Fi|Thriller
# 69  Action|Comedy|Horror|Thriller
# 70                         Action
# 75         Action|Sci-Fi|Thriller
# 77    Action|Crime|Drama|Thriller
# ...

# %%
movies[is_action].head(15)
# Out:
#     movieId                                      title  \
# 5         6                                Heat (1995)
# 8         9                        Sudden Death (1995)
# 9        10                           GoldenEye (1995)
# 14       15                    Cutthroat Island (1995)
# 19       20                         Money Train (1995)
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                                 genres
# 5                Action|Crime|Thriller
# ...
